# %%
# %load_ext sql
import settings

db_data=settings.database_connection(db_name='foodhub_legacy')

ENGINE=db_data['engine']
DATABASE_URI=db_data['database_uri']

# %sql $DATABASE_URI
with ENGINE.connect() as conn:
    print("Successfully connected!")
# Out:
# Successfully connected!

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/foodhub_legacy
# 1 rows affected.
# [('foodhub_flat',)]

# %%
# %sql select * from foodhub_flat limit 5;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/foodhub_legacy
# 5 rows affected.
# [(1, 'Amara Osei', 'Accra', 'Gold', 'Mama Rocks Burger', 'American', Decimal('4.5'), 'Classic Cheeseburger', 2, Decimal('18.00'), datetime.date(2024, 1, 10)),
#  (2, 'Amara Osei', 'Accra', 'Gold', 'Spice Route', 'Indian', Decimal('4.2'), 'Butter Chicken', 1, Decimal('9.50'), datetime.date(2024, 1, 12)),
#  (3, 'Fatima Al-Rashid', 'Nairobi', 'Silver', 'Dragon Palace', 'Chinese', Decimal('3.9'), 'Dim Sum Basket', 3, Decimal('22.50'), datetime.date(2024, 1, 13)),
#  (4, 'Fatima Al-Rashid', 'Nairobi', 'Silver', 'La Bella Italia', 'Italian', Decimal('4.7'), 'Margherita Pizza', 1, Decimal('14.00'), datetime.date(2024, 1, 14)),
#  (5, 'Kofi Mensah', 'Accra', 'Bronze', 'Nairobi Grill House', 'Kenyan', Decimal('4.3'), 'Nyama Choma Platter', 2, Decimal('20.00'), datetime.date(2024, 1, 15))]

# %%
# %%sql
# select count(*) as total_records
# from foodhub_flat;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/foodhub_legacy
# 1 rows affected.
# [(20,)]

# %%
# %%sql
# select customer_name, count(*) as appearances
# from foodhub_flat
# group by customer_name
# order by appearances desc;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/foodhub_legacy
# 10 rows affected.
# [('Amara Osei', 2),
#  ('Fatima Al-Rashid', 2),
#  ('Kofi Mensah', 2),
#  ('Zanele Dube', 2),
#  ('Emeka Eze', 2),
#  ('Priya Nair', 2),
#  ('David Kimani', 2),
#  ('Sofia Andrade', 2),
#  ('Liam Okonkwo', 2),
#  ('Aisha Conteh', 2)]
