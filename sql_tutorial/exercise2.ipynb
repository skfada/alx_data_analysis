# %%
# %load_ext sql
import settings

data = settings.database_connection('Chinook')

engine = data['engine']
db_uri = data['database_uri']

# %sql $db_uri
with engine.connect() as conn:
    print('Successfully connected!!')
# Out:
# Successfully connected!!

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/Chinook
# 11 rows affected.
# [('Album',),
#  ('Artist',),
#  ('Customer',),
#  ('Employee',),
#  ('Genre',),
#  ('Invoice',),
#  ('InvoiceLine',),
#  ('MediaType',),
#  ('Playlist',),
#  ('PlaylistTrack',),
#  ('Track',)]

# %%
# %%sql
# select * from Album limit 5;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/Chinook
# 5 rows affected.
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3)]

# %%
# %%sql
# select a.AlbumId, a.Title,t.Name
# from Album a
# left join Track t
# on a.Title = t.Name limit 5;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/Chinook
# 5 rows affected.
# [(2, 'Balls to the Wall', 'Balls to the Wall'),
#  (3, 'Restless and Wild', 'Restless and Wild'),
#  (4, 'Let There Be Rock', 'Let There Be Rock'),
#  (11, 'Out Of Exile', 'Out Of Exile'),
#  (16, 'Black Sabbath', 'Black Sabbath')]
