# %%
# %load_ext sql
import settings

data = settings.database_connection("Northwind")
database_uri = data['database_uri']
engine = data['engine']

# %sql $database_uri
with engine.connect() as conn:
    print('successfully connected!!!')
# Out:
# successfully connected!!!

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://skfada:***@127.0.0.1:3306/Northwind
# 12 rows affected.
# [('Categories',),
#  ('Courses',),
#  ('Customers',),
#  ('EmployeeTerritories',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Products',),
#  ('Region',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('Territories',)]
